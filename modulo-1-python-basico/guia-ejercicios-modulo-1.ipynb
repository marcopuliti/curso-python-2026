# %% [markdown]
# # Guía de ejercicios — Módulo 1: Python básico
#
# **Curso:** Python sin miedo — UNSL, FCFMyN
#
# **Entrega:** este mismo notebook con los ejercicios resueltos, antes del **viernes 02/10/2026**.
#
# **Estudiante:** *(completá tu nombre acá)*
#
# ## Pautas
#
# - Resolvé cada ejercicio en la celda de código que está debajo del enunciado. Podés agregar celdas si lo necesitás.
# - El trabajo es **individual**. Podés consultar apuntes, documentación y compañeros, pero el código entregado debe ser escrito por vos.
# - Si usaste un asistente de IA para *entender* algo (un concepto, un mensaje de error), decláralo en una celda de texto al final. Recordá que en este módulo el código debe ser tuyo.
# - Aprobación: al menos el 60 % de los ejercicios correctos. Los ejercicios marcados con ⭐ son desafíos opcionales: suman, pero no son necesarios para aprobar.
# - **Ejecutá `Kernel → Restart & Run All` antes de entregar** y verificá que todo corre sin errores de arriba a abajo.

# %% [markdown]
# ## Parte A — Variables, tipos y operadores
#
# ### Ejercicio 1 — Densidad
# Una muestra de roca tiene una masa de 847.3 g y un volumen de 312.5 cm³. Calculá su densidad y mostrala con 3 decimales, con un mensaje del estilo: `La densidad es 2.711 g/cm3`.

# %%
# Ejercicio 1

# %% [markdown]
# ### Ejercicio 2 — Tiempos de laboratorio
# Un experimento dura 9275 segundos. Usando división entera (`//`) y resto (`%`), expresá esa duración en horas, minutos y segundos, con un mensaje como: `El experimento dura 2 h, 34 min y 35 s`.

# %%
# Ejercicio 2

# %% [markdown]
# ### Ejercicio 3 — Verdadero o falso
# Sin ejecutar código, escribí en la celda de texto de abajo qué devuelve cada expresión (`True` o `False`) y por qué. Después verificá con código en la celda siguiente.
#
# ```python
# a) 7 / 2 == 3.5
# b) 7 // 2 == 3.5
# c) 10 % 3 == 1
# d) 2 ** 3 > 3 ** 2
# e) (5 > 3) and (2 != 2)
# f) not (4 < 1) or False
# ```

# %% [markdown]
# *Tus respuestas acá:*
#
# a)
# b)
# c)
# d)
# e)
# f)

# %%
# Verificación del Ejercicio 3

# %% [markdown]
# ## Parte B — Condicionales
#
# ### Ejercicio 4 — Año bisiesto
# Pedí un año por teclado y determiná si es bisiesto. Regla: es bisiesto si es divisible por 4, **excepto** los divisibles por 100 que no sean divisibles por 400. (1900 no fue bisiesto; 2000 sí; 2024 sí.)

# %%
# Ejercicio 4

# %% [markdown]
# ### Ejercicio 5 — Clasificación de sismos
# Pedí la magnitud de un sismo (escala Richter) y clasificalo: menor que 3.0 → 'micro', de 3.0 a 4.9 → 'menor', de 5.0 a 6.9 → 'moderado a fuerte', 7.0 o más → 'mayor'. Validá que la magnitud no sea negativa (si lo es, mostrar un mensaje de error).

# %%
# Ejercicio 5

# %% [markdown]
# ## Parte C — Bucles
#
# ### Ejercicio 6 — Suma selectiva
# Calculá la suma de todos los múltiplos de 3 o de 5 menores que 1000. (Verificación: 233168.)

# %%
# Ejercicio 6

# %% [markdown]
# ### Ejercicio 7 — Media de mediciones
# Escribí un programa que pida mediciones por teclado, una por una, hasta que el usuario escriba `fin`. Al terminar, debe mostrar cuántas mediciones se ingresaron, el promedio, el mínimo y el máximo. **Sin usar listas** (todavía no las vimos): resolvelo con variables acumuladoras.

# %%
# Ejercicio 7

# %% [markdown]
# ### Ejercicio 8 — Conjetura de Collatz
# Tomá un número natural `n`. Si es par, dividilo por 2; si es impar, calculá `3n + 1`. Repitiendo el proceso, la conjetura dice que siempre se llega a 1. Escribí un programa que, para `n = 27`, muestre la cantidad de pasos necesarios para llegar a 1 y el valor máximo alcanzado en el camino. (Verificación: 111 pasos, máximo 9232.)

# %%
# Ejercicio 8

# %% [markdown]
# ## Parte D — Funciones
#
# ### Ejercicio 9 — Caída libre
# Escribí una función `tiempo_de_caida(altura, gravedad=9.81)` que devuelva el tiempo que tarda un objeto en caer desde una altura dada: $t = \sqrt{2h/g}$. (Pista: la raíz cuadrada es elevar a la potencia `0.5`.) Usala para comparar el tiempo de caída desde 100 m en la Tierra ($g=9.81$), la Luna ($g=1.62$) y Marte ($g=3.71$), con docstring incluido.

# %%
# Ejercicio 9

# %% [markdown]
# ### Ejercicio 10 — Máximo común divisor
# Escribí una función `mcd(a, b)` que calcule el máximo común divisor con el algoritmo de Euclides: mientras `b` no sea 0, reemplazar `(a, b)` por `(b, a % b)`; al final el MCD es `a`. Verificá que `mcd(1071, 462)` dé 21. Después escribí `mcm(a, b)` (mínimo común múltiplo) **reutilizando** `mcd`: $\mathrm{mcm}(a,b) = \frac{a \cdot b}{\mathrm{mcd}(a,b)}$.

# %%
# Ejercicio 10

# %% [markdown]
# ### Ejercicio 11 — Interés compuesto / crecimiento exponencial
# Escribí una función `crecimiento(inicial, tasa, periodos)` que devuelva el valor final de una cantidad que crece a una tasa fija por período: $V = V_0 (1 + r)^n$. Usala para responder: si una población de células crece 8 % por hora, ¿cuántas horas tarda en duplicarse una población inicial de 1000 células? (Resolvelo llamando a la función dentro de un bucle.)

# %%
# Ejercicio 11

# %% [markdown]
# ### Ejercicio 12 ⭐ — Aproximación de raíces por Newton
# Para calcular $\sqrt{a}$, el método babilónico (caso particular de Newton) itera $x_{nuevo} = \frac{1}{2}\left(x + \frac{a}{x}\right)$ empezando con $x = a$. Escribí `raiz(a, tolerancia=1e-10)` que itere hasta que $|x_{nuevo} - x| <$ tolerancia y devuelva el resultado. Compará `raiz(2)` con `2 ** 0.5`. ¿Cuántas iteraciones necesitó? (Hacé que la función también lo informe.)

# %%
# Ejercicio 12

# %% [markdown]
# ### Ejercicio 13 ⭐ — Un problema de tu área
# Proponé y resolvé un mini-problema de **tu propio campo de investigación** usando lo visto en el módulo (variables, condicionales, bucles y al menos una función). Describí el problema en una celda de texto antes del código. Este ejercicio es el ensayo general del proyecto final.

# %% [markdown]
# *Descripción de tu problema acá:*

# %%
# Ejercicio 13

# %% [markdown]
# ---
#
# ## Declaración de uso de IA
#
# *Si usaste algún asistente de IA para entender conceptos o errores durante esta guía, indicá acá cuál y para qué. Si no usaste, escribí "No utilicé".*
